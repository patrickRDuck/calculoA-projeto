# %%
import sympy as smp
from sympy import *

# %%
from IPython.display import display

# %%
x, y = smp.symbols('x y')

# %%
smp.init_printing(use_latex='mathjax')

# %% [markdown]
# # 📘 Questão 2 — Derivadas
#
# Uma equipe de desenvolvedores está monitorando o consumo de memória RAM de uma aplicação complexa que realiza processamento de dados em tempo real. O uso de memória ao longo do tempo é representado por uma função M(t), que registra quantos gigabytes estão sendo utilizados em cada instante t.
#
# A derivada dessa função indica a taxa instantânea de crescimento ou liberação de memória, informação essencial para detectar vazamentos de memória, gargalos e picos inesperados durante a execução.
#
# Com base nesse cenário, as questões abaixo mostrarão os momentos quando o consumo aumenta rapidamente, se estabiliza ou diminui, utilizando o conceito de taxa de variação instantânea.

# %%
#Questão 2A
derivada2A = smp.Derivative((2*x**4-4*x**2), x)

print('Derivação direta pela fórmula da tabela, número 1 (regra da potência):')
display(derivada2A)

print(f'Resultado da derivação é igual a:')
display(derivada2A.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 1 (regra da potência):
# d ⎛   4      2⎞
# ──⎝2⋅x  - 4⋅x ⎠
# dx
# Resultado da derivação é igual a:
#    3
# 8⋅x  - 8⋅x

# %%
#Questão 2B
derivada2B = smp.Derivative((3*x**2-1)*(4*x+3), x)

print('Derivação direta pela fórmula da tabela, número 2 (regra do produto):')
display(derivada2B)

print(f'Resultado da derivação é igual a:')
display(derivada2B.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 1 (regra da potência):
# d ⎛          ⎛   2    ⎞⎞
# ──⎝(4⋅x + 3)⋅⎝3⋅x  - 1⎠⎠
# dx
# Resultado da derivação é igual a:
#     2
# 12⋅x  + 6⋅x⋅(4⋅x + 3) - 4

# %%
#Questão 2C
derivada2C = smp.Derivative((-x**3+1)/(3*x-5), x)

print('Derivação direta pela fórmula da tabela, número 3 (regra do quociente):')
display(derivada2C)

print(f'Resultado da derivação é igual a:')
display(derivada2C.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 3 (regra do quociente):
#   ⎛     3 ⎞
# d ⎜1 - x  ⎟
# ──⎜───────⎟
# dx⎝3⋅x - 5⎠
# Resultado da derivação é igual a:
#       2       ⎛     3⎞
#    3⋅x      3⋅⎝1 - x ⎠
# - ─────── - ──────────
#   3⋅x - 5            2
#             (3⋅x - 5)

# %%
#Questão 2D -3**x 
derivada2D = smp.Derivative(-3**x , x)

print('Derivação direta pela fórmula da tabela, número 4:')
display(derivada2D)

print(f'Resultado da derivação é igual a:')
display(derivada2D.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 4:
# d ⎛  x⎞
# ──⎝-3 ⎠
# dx
# Resultado da derivação é igual a:
#   x
# -3 ⋅log(3)

# %%
#Questão 2E 
derivada2D = smp.Derivative((6*x**3-4)**4 , x)

print('Derivação direta pela fórmula da tabela, número 5:')
display(derivada2D)

print(f'Resultado da derivação é igual a:')
display(derivada2D.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 5:
#   ⎛          4⎞
# d ⎜⎛   3    ⎞ ⎟
# ──⎝⎝6⋅x  - 4⎠ ⎠
# dx
# Resultado da derivação é igual a:
#                 3
#     2 ⎛   3    ⎞
# 72⋅x ⋅⎝6⋅x  - 4⎠

# %%
#Questão 2F 
derivada2F = smp.Derivative(smp.log(x)**4 , x)

print('Derivação direta pela fórmula da tabela, número 6:')
display(derivada2F)

print(f'Resultado da derivação é igual a:')
display(derivada2F.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 6:
# d ⎛   4   ⎞
# ──⎝log (x)⎠
# dx
# Resultado da derivação é igual a:
#      3
# 4⋅log (x)
# ─────────
#     x

# %%
#Questão 2G 
derivada2G = smp.Derivative(smp.ln(x,10), x)

print('Derivação direta pela fórmula da tabela, número 7:')
display(derivada2G)

print(f'Resultado da derivação é igual a:')
display(derivada2G.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 7:
# d ⎛log(x) ⎞
# ──⎜───────⎟
# dx⎝log(10)⎠
# Resultado da derivação é igual a:
#     1
# ─────────
# x⋅log(10)

# %%
#Questão 2H
derivada2H = smp.Derivative((2*x + 1)**smp.cos(x), x)

print('Derivação direta pela fórmula da tabela, número 8:')
display(derivada2H)

print(f'Resultado da derivação é igual a:')
display(derivada2H.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 7:
# d ⎛         cos(x)⎞
# ──⎝(2⋅x + 1)      ⎠
# dx
# Resultado da derivação é igual a:
#          cos(x) ⎛                       2⋅cos(x)⎞
# (2⋅x + 1)      ⋅⎜-log(2⋅x + 1)⋅sin(x) + ────────⎟
#                 ⎝                       2⋅x + 1 ⎠

# %%
#Questão 2I
derivada2I = smp.Derivative(smp.sin(3*x**2 + 4*x - 1), x)

print('Derivação direta pela fórmula da tabela, número 9:')
display(derivada2I)

print(f'Resultado da derivação é igual a:')
display(derivada2I.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 9:
# d ⎛   ⎛   2          ⎞⎞
# ──⎝sin⎝3⋅x  + 4⋅x - 1⎠⎠
# dx
# Resultado da derivação é igual a:
#              ⎛   2          ⎞
# (6⋅x + 4)⋅cos⎝3⋅x  + 4⋅x - 1⎠

# %%
#Questão 2J
derivada2J = smp.Derivative(smp.cos(5*x**3 - 2*x + 7), x)

print('Derivação direta pela fórmula da tabela, número 10:')
display(derivada2J) 

print(f'Resultado da derivação é igual a:')
display(derivada2J.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 10:
# d ⎛   ⎛   3          ⎞⎞
# ──⎝cos⎝5⋅x  - 2⋅x + 7⎠⎠
# dx
# Resultado da derivação é igual a:
#  ⎛    2    ⎞    ⎛   3          ⎞
# -⎝15⋅x  - 2⎠⋅sin⎝5⋅x  - 2⋅x + 7⎠

# %%
#Questão 2K
derivada2K = smp.Derivative(smp.tan(4*x**3 - 5*x + 2), x)

print('Derivação direta pela fórmula da tabela, número 11:')
display(derivada2K) 

print(f'Resultado da derivação é igual a:')
display(derivada2K.doit())
# Out:
# Derivação direta pela fórmula da tabela, número 11:
# d ⎛   ⎛   3          ⎞⎞
# ──⎝tan⎝4⋅x  - 5⋅x + 2⎠⎠
# dx
# Resultado da derivação é igual a:
# ⎛    2    ⎞ ⎛   2⎛   3          ⎞    ⎞
# ⎝12⋅x  - 5⎠⋅⎝tan ⎝4⋅x  - 5⋅x + 2⎠ + 1⎠

# %%
#Questão 2L
derivada2L = smp.Derivative((3*x**2 -4*x + 1)**5, x)

print('Derivação pela regra da cadeia:')
display(derivada2L) 

print(f'Resultado da derivação é igual a:')
display(derivada2L.doit())
# Out:
# Derivação pela regra da cadeia:
#   ⎛                5⎞
# d ⎜⎛   2          ⎞ ⎟
# ──⎝⎝3⋅x  - 4⋅x + 1⎠ ⎠
# dx
# Resultado da derivação é igual a:
#                             4
#             ⎛   2          ⎞
# (30⋅x - 20)⋅⎝3⋅x  - 4⋅x + 1⎠

# %%
#Questão 2M
derivada2M = smp.Derivative(1 / (2*x**2 - 3*x + 5)**-4, x)

print('Derivação pela regra da cadeia usando regra do quociente:')
display(derivada2M) 

print(f'Resultado da derivação é igual a:')
display(derivada2M.doit())
# Out:
# Derivação pela regra da cadeia usando regra do quociente:
#   ⎛                4⎞
# d ⎜⎛   2          ⎞ ⎟
# ──⎝⎝2⋅x  - 3⋅x + 5⎠ ⎠
# dx
# Resultado da derivação é igual a:
#                             3
#             ⎛   2          ⎞
# (16⋅x - 12)⋅⎝2⋅x  - 3⋅x + 5⎠

# %%
#Questão 2N
derivada2N = smp.Derivative((4*x**2 -3*x + 1) * (2*x + 7), x)

print('Derivação pela regra da cadeia usando regra do produto:')
display(derivada2N) 

print(f'Resultado da derivação é igual a:')
display(derivada2N.doit())
# Out:
# Derivação pela regra da cadeia usando regra do produto:
# d ⎛          ⎛   2          ⎞⎞
# ──⎝(2⋅x + 7)⋅⎝4⋅x  - 3⋅x + 1⎠⎠
# dx
# Resultado da derivação é igual a:
#    2
# 8⋅x  - 6⋅x + (2⋅x + 7)⋅(8⋅x - 3) + 2

# %%
#Questão 2O
derivada2O = smp.Derivative(smp.sin(3*x**2 + 1)/(x**2 + 4), x)

print('Derivação pela regra da cadeia usando regra do quociente trigonométrico:')
display(derivada2O) 

print(f'Resultado da derivação é igual a:')
display(derivada2O.doit())
# Out:
# Derivação pela regra da cadeia usando regra do quociente trigonométrico:
#   ⎛   ⎛   2    ⎞⎞
# d ⎜sin⎝3⋅x  + 1⎠⎟
# ──⎜─────────────⎟
# dx⎜    2        ⎟
#   ⎝   x  + 4    ⎠
# Resultado da derivação é igual a:
#        ⎛   2    ⎞          ⎛   2    ⎞
# 6⋅x⋅cos⎝3⋅x  + 1⎠   2⋅x⋅sin⎝3⋅x  + 1⎠
# ───────────────── - ─────────────────
#       2                         2
#      x  + 4             ⎛ 2    ⎞
#                         ⎝x  + 4⎠

# %%
#Questão 2P
derivada2P = smp.Derivative(smp.sin(3*x**2 - 1) * smp.cos(2*x + 5), x)

print('Derivação pela regra da cadeia usando regra do produto trigonométrico:')
display(derivada2P) 

print(f'Resultado da derivação é igual a:')
display(derivada2P.doit())
# Out:
# Derivação pela regra da cadeia usando regra do produto trigonométrico:
# d ⎛   ⎛   2    ⎞             ⎞
# ──⎝sin⎝3⋅x  - 1⎠⋅cos(2⋅x + 5)⎠
# dx
# Resultado da derivação é igual a:
#                     ⎛   2    ⎞                     ⎛   2    ⎞
# 6⋅x⋅cos(2⋅x + 5)⋅cos⎝3⋅x  - 1⎠ - 2⋅sin(2⋅x + 5)⋅sin⎝3⋅x  - 1⎠
